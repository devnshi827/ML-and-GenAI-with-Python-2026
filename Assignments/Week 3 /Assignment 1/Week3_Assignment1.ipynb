# %% [markdown]
# Week-3, Assignment:1

# %% [markdown]
# Exploratory Data Analysis (EDA) and
# Machine Learning on Agricultural Yield Dataset

# %% [markdown]
# Q1. Dataset Overview
# Load the dataset and answer the following:

# %% [markdown]
# a. How many rows and columns are present?

# %%
import pandas as pd

df = pd.read_csv("agriculture_yield_dataset.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1500
# Columns: 8

# %% [markdown]
# b. What are the names of all columns?

# %%
print(df.columns.tolist())
# Out:
# ['rainfall_mm', 'temperature_c', 'fertilizer_kg', 'irrigation_hours', 'soil_ph', 'crop_type', 'soil_type', 'yield_ton_per_hectare']

# %% [markdown]
# c. Display the first 10 records.

# %%
print(df.head(10))
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
# 5        831.9           28.0          190.3               2.1      6.1
# 6       1023.8           32.0          108.5               6.9      6.2
# 7       1142.4           18.4          241.9               4.1      7.3
# 8        810.4           36.4          164.8               9.9      6.5
# 9       1085.5           29.4           89.3               8.3      5.8
#
#   crop_type soil_type  yield_ton_per_hectare
# 0     Maize     Loamy                   5.92
# 1     Maize     Sandy                   6.24
# ...

# %% [markdown]
# Q2. Data Types and Missing Values

# %% [markdown]
# a. Check the data type of each column.

# %%
print(df.dtypes)
# Out:
# rainfall_mm              float64
# temperature_c            float64
# fertilizer_kg            float64
# irrigation_hours         float64
# soil_ph                  float64
# crop_type                 object
# soil_type                 object
# yield_ton_per_hectare    float64
# dtype: object

# %% [markdown]
# b. Identify whether any missing values are present.

# %%
print(df.isnull().sum())
# Out:
# rainfall_mm              0
# temperature_c            0
# fertilizer_kg            0
# irrigation_hours         0
# soil_ph                  0
# crop_type                0
# soil_type                0
# yield_ton_per_hectare    0
# dtype: int64

# %% [markdown]
# c. If missing values exist, mention the affected columns.

# %%
print(df.columns[df.isnull().any()].tolist())
# Out:
# []

# %% [markdown]
# 3. Descriptive Statistics
# Generate summary statistics for all numerical features and answer:

# %%
print(df.describe())
# Out:
#        rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  \
# count  1500.000000    1500.000000    1500.000000       1500.000000
# mean    754.054667      27.749467     148.744067          5.403267
# std     255.097216       5.758101      56.990279          2.584329
# min     300.200000      18.000000      50.300000          1.000000
# 25%     536.175000      22.600000      98.600000          3.200000
# 50%     761.200000      27.700000     146.850000          5.400000
# 75%     964.375000      32.600000     196.575000          7.600000
# max    1200.000000      38.000000     249.900000         10.000000
#
#            soil_ph  yield_ton_per_hectare
# count  1500.000000            1500.000000
# mean      6.759133               5.028793
# std       0.719742               0.968282
# min       5.500000               2.090000
# 25%       6.100000               4.337500
# 50%       6.800000               5.010000
# 75%       7.400000               5.740000
# ...

# %% [markdown]
# a. Which feature has the highest mean value?

# %%
print(df.mean(numeric_only=True))
# Out:
# rainfall_mm              754.054667
# temperature_c             27.749467
# fertilizer_kg            148.744067
# irrigation_hours           5.403267
# soil_ph                    6.759133
# yield_ton_per_hectare      5.028793
# dtype: float64

# %% [markdown]
# Answer: rainfall_mm has the highest mean value.

# %% [markdown]
# b. Which feature has the highest standard deviation?

# %%
print(df.std(numeric_only=True))
# Out:
# rainfall_mm              255.097216
# temperature_c              5.758101
# fertilizer_kg             56.990279
# irrigation_hours           2.584329
# soil_ph                    0.719742
# yield_ton_per_hectare      0.968282
# dtype: float64

# %% [markdown]
# Answer: rainfall_mm has the highest standard deviation.

# %% [markdown]
# Part B: Exploratory Data Analysis (EDA)
# Q4. Distribution Analysis
# Create histograms for:
# 1. rainfall_mm
# 2. temperature_c
# 3. fertilizer_kg
# 4. yield_ton_per_hectare
# Write 2–3 observations from each histogram.

# %%
import matplotlib.pyplot as plt

plt.hist(df['rainfall_mm'], bins=20)
plt.title('Rainfall Distribution')
plt.xlabel('rainfall_mm')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observations:
# 1. Rainfall values are spread over a wide range.
# 2. Distribution is fairly uniform.
# 3. No major outliers are visible.

# %%
plt.hist(df['temperature_c'], bins=20)
plt.title('Temperature Distribution')
plt.xlabel('temperature_c')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observations:
# 1. Temperature values are evenly distributed.
# 2. No strong skewness is observed.
# 3. Most values lie within the expected range.

# %%
plt.hist(df['fertilizer_kg'], bins=20)
plt.title('Fertilizer Distribution')
plt.xlabel('fertilizer_kg')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observations:
# 1. Fertilizer usage is distributed across the full range.
# 2. Most observations occur in middle ranges.
# 3. No extreme outliers are visible.

# %%
plt.hist(df['yield_ton_per_hectare'], bins=20)
plt.title('Yield Distribution')
plt.xlabel('yield_ton_per_hectare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Observations:
# 1. Distribution is approximately bell-shaped.
# 2. Most yields are concentrated around the center.
# 3. Few extreme values exist.

# %% [markdown]
# Q5. Crop Type Analysis
# a. Find the number of records for each crop type

# %%
print(df['crop_type'].value_counts())
# Out:
# crop_type
# Cotton     311
# Soybean    306
# Wheat      303
# Rice       293
# Maize      287
# Name: count, dtype: int64

# %% [markdown]
# b. Create a count plot (bar chart) for crop_type.

# %%
import seaborn as sns

sns.countplot(data=df, x='crop_type')
plt.show()

# %% [markdown]
# c. Which crop appears most frequently?

# %%
print(df['crop_type'].value_counts().idxmax())
# Out:
# Cotton

# %% [markdown]
# Q6. Soil Type Analysis
# a. Find the frequency of each soil type.

# %%
print(df['soil_type'].value_counts())
# Out:
# soil_type
# Clay     534
# Sandy    492
# Loamy    474
# Name: count, dtype: int64

# %% [markdown]
# b. Create a count plot for soil_type.

# %%
sns.countplot(data=df, x='soil_type')
plt.show()

# %% [markdown]
# c. Which soil type is most common?

# %%
print(df['soil_type'].value_counts().idxmax())
# Out:
# Clay

# %% [markdown]
# Q7. Yield Distribution
# Create a histogram of yield_ton_per_hectare.
# Answer:
# 1. Is the distribution approximately normal?
# 2. Are there any noticeable outliers?

# %%
plt.hist(df['yield_ton_per_hectare'], bins=20)
plt.title('Yield Distribution')
plt.xlabel('yield_ton_per_hectare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Answer: 1. Yes, the distribution is approxmimately normal.
# 2. No significant outliers are observed.

# %% [markdown]
# Q8. Scatter Plot Analysis
# Create scatter plots of:
# 1. rainfall_mm vs yield_ton_per_hectare

# %%
plt.scatter(df['rainfall_mm'],
            df['yield_ton_per_hectare'])
plt.xlabel('rainfall_mm')
plt.ylabel('yield_ton_per_hectare')
plt.show()

# %% [markdown]
# 2. fertilizer_kg vs yield_ton_per_hectare

# %%
plt.scatter(df['fertilizer_kg'],
            df['yield_ton_per_hectare'])
plt.xlabel('fertilizer_kg')
plt.ylabel('yield_ton_per_hectare')
plt.show()

# %%
print(df[['rainfall_mm',
          'fertilizer_kg',
          'yield_ton_per_hectare']].corr())
# Out:
#                        rainfall_mm  fertilizer_kg  yield_ton_per_hectare
# rainfall_mm               1.000000       0.002558               0.553704
# fertilizer_kg             0.002558       1.000000               0.278043
# yield_ton_per_hectare     0.553704       0.278043               1.000000

# %% [markdown]
# Answer: rainfall_mm appears to have a stronger relationship with yield.

# %% [markdown]
# Q9. Correlation Analysis
# a. Generate a correlation matrix for numerical features.

# %%
corr_matrix = df.select_dtypes(include='number').corr()

print(corr_matrix)
# Out:
#                        rainfall_mm  temperature_c  fertilizer_kg  \
# rainfall_mm               1.000000       0.026721       0.002558
# temperature_c             0.026721       1.000000       0.037468
# fertilizer_kg             0.002558       0.037468       1.000000
# irrigation_hours          0.010877       0.007114      -0.010497
# soil_ph                   0.006916       0.001513       0.010001
# yield_ton_per_hectare     0.553704      -0.022559       0.278043
#
#                        irrigation_hours   soil_ph  yield_ton_per_hectare
# rainfall_mm                    0.010877  0.006916               0.553704
# temperature_c                  0.007114  0.001513              -0.022559
# fertilizer_kg                 -0.010497  0.010001               0.278043
# irrigation_hours               1.000000  0.009307               0.542664
# soil_ph                        0.009307  1.000000               0.024412
# yield_ton_per_hectare          0.542664  0.024412               1.000000

# %% [markdown]
# b. Create a heatmap.

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm'
)

plt.show()

# %% [markdown]
# c. Identify the top three features most correlated with crop yield.

# %%
corr_with_yield = corr_matrix['yield_ton_per_hectare']

print(
    corr_with_yield.sort_values(
        ascending=False
    )
)
# Out:
# yield_ton_per_hectare    1.000000
# rainfall_mm              0.553704
# irrigation_hours         0.542664
# fertilizer_kg            0.278043
# soil_ph                  0.024412
# temperature_c           -0.022559
# Name: yield_ton_per_hectare, dtype: float64

# %% [markdown]
# Answer: The top three features most correlated with crop yield are:
# 1. rainfall_mm
# 2. irrigation_hours
# 3. fertilizer_kg

# %% [markdown]
# Q10. Group-Based Analysis
# Calculate the average yield for:
# a. Each crop type

# %%
print(
    df.groupby('crop_type')
      ['yield_ton_per_hectare']
      .mean()
)
# Out:
# crop_type
# Cotton     4.607299
# Maize      4.897143
# Rice       5.494744
# Soybean    5.173431
# Wheat      4.989472
# Name: yield_ton_per_hectare, dtype: float64

# %% [markdown]
# b. Each soil type.

# %%
print(
    df.groupby('soil_type')
      ['yield_ton_per_hectare']
      .mean()
)
# Out:
# soil_type
# Clay     5.134326
# Loamy    5.366519
# Sandy    4.588882
# Name: yield_ton_per_hectare, dtype: float64

# %% [markdown]
# Which crop and soil type have the highest average yield?

# %%
print(
    df.groupby('crop_type')
      ['yield_ton_per_hectare']
      .mean()
      .idxmax()
)
# Out:
# Rice

# %%
print(
    df.groupby('soil_type')
      ['yield_ton_per_hectare']
      .mean()
      .idxmax()
)
# Out:
# Loamy

# %% [markdown]
# Part C: Data Preparation
# Q11. Feature Encoding
# The dataset contains categorical variables.
# 1. Identify the categorical columns.

# %%
print(
    df.select_dtypes(
        include='object'
    ).columns.tolist()
)
# Out:
# ['crop_type', 'soil_type']

# %% [markdown]
# 2. Convert them into numerical form using One-Hot Encoding.

# %%
df_encoded = pd.get_dummies(
    df,
    columns=['crop_type','soil_type']
)

print(df_encoded.head())
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Cotton  crop_type_Maize  crop_type_Rice  \
# 0                   5.92             False             True           False
# 1                   6.24             False             True           False
# 2                   4.77             False            False           False
# 3                   4.04             False             True           False
# 4                   5.17              True            False           False
#
#    crop_type_Soybean  crop_type_Wheat  soil_type_Clay  soil_type_Loamy  \
# ...

# %% [markdown]
# 3. Display the first five rows of the transformed dataset.

# %%
print(df_encoded.head())
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Cotton  crop_type_Maize  crop_type_Rice  \
# 0                   5.92             False             True           False
# 1                   6.24             False             True           False
# 2                   4.77             False            False           False
# 3                   4.04             False             True           False
# 4                   5.17              True            False           False
#
#    crop_type_Soybean  crop_type_Wheat  soil_type_Clay  soil_type_Loamy  \
# ...

# %% [markdown]
# Q12. Feature Selection
# Separate:
# 1. Input features (X)
# 2. Target variable (y)
# Specify which column is being used as the target variable.

# %%
X = df_encoded.drop(
    'yield_ton_per_hectare',
    axis=1
)

print(X.head())
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    crop_type_Cotton  crop_type_Maize  crop_type_Rice  crop_type_Soybean  \
# 0             False             True           False              False
# 1             False             True           False              False
# 2             False            False           False              False
# 3             False             True           False              False
# 4              True            False           False              False
#
#    crop_type_Wheat  soil_type_Clay  soil_type_Loamy  soil_type_Sandy
# ...

# %%
y = df_encoded['yield_ton_per_hectare']

print(y.head())
# Out:
# 0    5.92
# 1    6.24
# 2    4.77
# 3    4.04
# 4    5.17
# Name: yield_ton_per_hectare, dtype: float64

# %% [markdown]
# Part D: Machine Learning
# Q13. Train-Test Split
# Split the dataset into:
# 1. 80% Training Data
# 2. 20% Testing Data
# Display the shape of:
# 1. X_train
# 2. X_test
# 3. y_train
# 4. y_test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
# Out:
# (1200, 13)

# %%
print(X_test.shape)
# Out:
# (300, 13)

# %%
print(y_train.shape)
# Out:
# (1200,)

# %%
print(y_test.shape)
# Out:
# (300,)

# %% [markdown]
# Q14. Linear Regression Model
# 1. Train a Linear Regression model.
# 2. Display the model coefficients and intercept.
# 3. Which feature has the highest positive coefficient?

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(
    X_train,
    y_train
)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# 1.9111026182800726

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})

print(coef_df)
# Out:
#               Feature  Coefficient
# 0         rainfall_mm     0.002035
# 1       temperature_c    -0.009175
# 2       fertilizer_kg     0.004978
# 3    irrigation_hours     0.198327
# 4             soil_ph     0.004901
# 5    crop_type_Cotton    -0.386623
# 6     crop_type_Maize    -0.147693
# 7      crop_type_Rice     0.477369
# 8   crop_type_Soybean     0.095096
# 9     crop_type_Wheat    -0.038149
# 10     soil_type_Clay     0.062653
# 11    soil_type_Loamy     0.365627
# 12    soil_type_Sandy    -0.428280

# %%
coef_df.sort_values(
    by='Coefficient',
    ascending=False
)
# Out:
#               Feature  Coefficient
# 7      crop_type_Rice     0.477369
# 11    soil_type_Loamy     0.365627
# 3    irrigation_hours     0.198327
# 8   crop_type_Soybean     0.095096
# 10     soil_type_Clay     0.062653
# 2       fertilizer_kg     0.004978
# 4             soil_ph     0.004901
# 0         rainfall_mm     0.002035
# 1       temperature_c    -0.009175
# 9     crop_type_Wheat    -0.038149
# 6     crop_type_Maize    -0.147693
# 5    crop_type_Cotton    -0.386623
# 12    soil_type_Sandy    -0.428280

# %% [markdown]
# Answer: crop_type_Rice
